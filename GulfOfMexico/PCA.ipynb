% %%
EXPLAINED_VARIANCE_THRESHOLD = 0.99;

% %%
datapath = '../../box/Data/GulfOfMexico/processed data';

% %% [markdown]
% # 9-24

% %%
load([datapath filesep 'processed_data_09-24.mat']);

% %% [markdown]
% ### Cross-polarized data

% %%
[xpol_principal_components, xpol_transformed_data, xpol_variances] = pca(data.xpol_processed');
xpol_transformed_data = xpol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
xpol_explained_variance = cumsum(xpol_variances/(sum(xpol_variances)));
stem(xpol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
xpol_num_components = find(xpol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% xpol_num_components =
%
%      8

% %% [markdown]
% ### Copolarized data

% %%
[copol_principal_components, copol_transformed_data, copol_variances] = pca(data.copol_processed');
copol_transformed_data = copol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
copol_explained_variance = cumsum(copol_variances/(sum(copol_variances)));
stem(copol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
copol_num_components = find(copol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% copol_num_components =
%
%      3

% %% [markdown]
% ### project and save the data

% %%
data.xpol_pca = xpol_transformed_data(1:xpol_num_components, :);
data.copol_pca = copol_transformed_data(1:copol_num_components, :);
save([datapath filesep 'processed_data_pca_09-24.mat'], 'data', '-v7.3');

% %% [markdown]
% # 9-25

% %%
load([datapath filesep 'processed_data_09-25.mat']);

% %% [markdown]
% ### Cross-polarized data

% %%
[xpol_principal_components, xpol_transformed_data, xpol_variances] = pca(data.xpol_processed');
xpol_transformed_data = xpol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
xpol_explained_variance = cumsum(xpol_variances/(sum(xpol_variances)));
stem(xpol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
xpol_num_components = find(xpol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% xpol_num_components =
%
%      5

% %% [markdown]
% ### Copolarized data

% %%
[copol_principal_components, copol_transformed_data, copol_variances] = pca(data.copol_processed');
copol_transformed_data = copol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
copol_explained_variance = cumsum(copol_variances/(sum(copol_variances)));
stem(copol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
copol_num_components = find(copol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% copol_num_components =
%
%      4

% %% [markdown]
% ### project and save the data

% %%
data.xpol_pca = xpol_transformed_data(1:xpol_num_components, :);
data.copol_pca = copol_transformed_data(1:copol_num_components, :);
save([datapath filesep 'processed_data_pca_09-25.mat'], 'data', '-v7.3');

% %% [markdown]
% # 9-26

% %%
load([datapath filesep 'processed_data_09-26.mat']);

% %% [markdown]
% ### Cross-polarized data

% %%
[xpol_principal_components, xpol_transformed_data, xpol_variances] = pca(data.xpol_processed');
xpol_transformed_data = xpol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
xpol_explained_variance = cumsum(xpol_variances/(sum(xpol_variances)));
stem(xpol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
xpol_num_components = find(xpol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% xpol_num_components =
%
%      5

% %% [markdown]
% ### Copolarized data

% %%
[copol_principal_components, copol_transformed_data, copol_variances] = pca(data.copol_processed');
copol_transformed_data = copol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
copol_explained_variance = cumsum(copol_variances/(sum(copol_variances)));
stem(copol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
copol_num_components = find(copol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% copol_num_components =
%
%      3

% %% [markdown]
% ### project and save the data

% %%
data.xpol_pca = xpol_transformed_data(1:xpol_num_components, :);
data.copol_pca = copol_transformed_data(1:copol_num_components, :);
save([datapath filesep 'processed_data_pca_09-26.mat'], 'data', '-v7.3');

% %% [markdown]
% # 9-29

% %%
load([datapath filesep 'processed_data_09-29.mat']);

% %% [markdown]
% ### Cross-polarized data

% %%
[xpol_principal_components, xpol_transformed_data, xpol_variances] = pca(data.xpol_processed');
xpol_transformed_data = xpol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
xpol_explained_variance = cumsum(xpol_variances/(sum(xpol_variances)));
stem(xpol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
xpol_num_components = find(xpol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% xpol_num_components =
%
%      7

% %% [markdown]
% ### Copolarized data

% %%
[copol_principal_components, copol_transformed_data, copol_variances] = pca(data.copol_processed');
copol_transformed_data = copol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
copol_explained_variance = cumsum(copol_variances/(sum(copol_variances)));
stem(copol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
copol_num_components = find(copol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% copol_num_components =
%
%      4

% %% [markdown]
% ### project and save the data

% %%
data.xpol_pca = xpol_transformed_data(1:xpol_num_components, :);
data.copol_pca = copol_transformed_data(1:copol_num_components, :);
save([datapath filesep 'processed_data_pca_09-29.mat'], 'data', '-v7.3');

% %% [markdown]
% # 9-30

% %%
load([datapath filesep 'processed_data_09-30.mat']);

% %% [markdown]
% ### Cross-polarized data

% %%
[xpol_principal_components, xpol_transformed_data, xpol_variances] = pca(data.xpol_processed');
xpol_transformed_data = xpol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
xpol_explained_variance = cumsum(xpol_variances/(sum(xpol_variances)));
stem(xpol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
xpol_num_components = find(xpol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% xpol_num_components =
%
%      6

% %% [markdown]
% ### Copolarized data

% %%
[copol_principal_components, copol_transformed_data, copol_variances] = pca(data.copol_processed');
copol_transformed_data = copol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
copol_explained_variance = cumsum(copol_variances/(sum(copol_variances)));
stem(copol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
copol_num_components = find(copol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% copol_num_components =
%
%      3

% %% [markdown]
% ### project and save the data

% %%
data.xpol_pca = xpol_transformed_data(1:xpol_num_components, :);
data.copol_pca = copol_transformed_data(1:copol_num_components, :);
save([datapath filesep 'processed_data_pca_09-30.mat'], 'data', '-v7.3');

% %% [markdown]
% # 10-01

% %%
load([datapath filesep 'processed_data_10-01.mat']);

% %% [markdown]
% ### Cross-polarized data

% %%
[xpol_principal_components, xpol_transformed_data, xpol_variances] = pca(data.xpol_processed');
xpol_transformed_data = xpol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
xpol_explained_variance = cumsum(xpol_variances/(sum(xpol_variances)));
stem(xpol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
xpol_num_components = find(xpol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% xpol_num_components =
%
%      6

% %% [markdown]
% ### Copolarized data

% %%
[copol_principal_components, copol_transformed_data, copol_variances] = pca(data.copol_processed');
copol_transformed_data = copol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
copol_explained_variance = cumsum(copol_variances/(sum(copol_variances)));
stem(copol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
copol_num_components = find(copol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% copol_num_components =
%
%      3

% %% [markdown]
% ### project and save the data

% %%
data.xpol_pca = xpol_transformed_data(1:xpol_num_components, :);
data.copol_pca = copol_transformed_data(1:copol_num_components, :);
save([datapath filesep 'processed_data_pca_10-01.mat'], 'data', '-v7.3');

% %% [markdown]
% # 10-02

% %%
load([datapath filesep 'processed_data_10-02.mat']);

% %% [markdown]
% ### Cross-polarized data

% %%
[xpol_principal_components, xpol_transformed_data, xpol_variances] = pca(data.xpol_processed');
xpol_transformed_data = xpol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
xpol_explained_variance = cumsum(xpol_variances/(sum(xpol_variances)));
stem(xpol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
xpol_num_components = find(xpol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% xpol_num_components =
%
%      5

% %% [markdown]
% ### Copolarized data

% %%
[copol_principal_components, copol_transformed_data, copol_variances] = pca(data.copol_processed');
copol_transformed_data = copol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
copol_explained_variance = cumsum(copol_variances/(sum(copol_variances)));
stem(copol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
copol_num_components = find(copol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% copol_num_components =
%
%      3

% %% [markdown]
% ### project and save the data

% %%
data.xpol_pca = xpol_transformed_data(1:xpol_num_components, :);
data.copol_pca = copol_transformed_data(1:copol_num_components, :);
save([datapath filesep 'processed_data_pca_10-02.mat'], 'data', '-v7.3');

% %% [markdown]
% # 10-03

% %%
load([datapath filesep 'processed_data_10-03.mat']);

% %% [markdown]
% ### Cross-polarized data

% %%
[xpol_principal_components, xpol_transformed_data, xpol_variances] = pca(data.xpol_processed');
xpol_transformed_data = xpol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
xpol_explained_variance = cumsum(xpol_variances/(sum(xpol_variances)));
stem(xpol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
xpol_num_components = find(xpol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% xpol_num_components =
%
%      6

% %% [markdown]
% ### Copolarized data

% %%
[copol_principal_components, copol_transformed_data, copol_variances] = pca(data.copol_processed');
copol_transformed_data = copol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
copol_explained_variance = cumsum(copol_variances/(sum(copol_variances)));
stem(copol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
copol_num_components = find(copol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% copol_num_components =
%
%      3

% %% [markdown]
% ### project and save the data

% %%
data.xpol_pca = xpol_transformed_data(1:xpol_num_components, :);
data.copol_pca = copol_transformed_data(1:copol_num_components, :);
save([datapath filesep 'processed_data_pca_10-03.mat'], 'data', '-v7.3');

% %% [markdown]
% # 10-04

% %%
load([datapath filesep 'processed_data_10-04.mat']);

% %% [markdown]
% ### Cross-polarized data

% %%
[xpol_principal_components, xpol_transformed_data, xpol_variances] = pca(data.xpol_processed');
xpol_transformed_data = xpol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
xpol_explained_variance = cumsum(xpol_variances/(sum(xpol_variances)));
stem(xpol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
xpol_num_components = find(xpol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% xpol_num_components =
%
%      8

% %% [markdown]
% ### Copolarized data

% %%
[copol_principal_components, copol_transformed_data, copol_variances] = pca(data.copol_processed');
copol_transformed_data = copol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
copol_explained_variance = cumsum(copol_variances/(sum(copol_variances)));
stem(copol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
copol_num_components = find(copol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% copol_num_components =
%
%      5

% %% [markdown]
% ### project and save the data

% %%
data.xpol_pca = xpol_transformed_data(1:xpol_num_components, :);
data.copol_pca = copol_transformed_data(1:copol_num_components, :);
save([datapath filesep 'processed_data_pca_10-04.mat'], 'data', '-v7.3');

% %% [markdown]
% # 10-05

% %%
load([datapath filesep 'processed_data_10-05.mat']);

% %% [markdown]
% ### Cross-polarized data

% %%
[xpol_principal_components, xpol_transformed_data, xpol_variances] = pca(data.xpol_processed');
xpol_transformed_data = xpol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
xpol_explained_variance = cumsum(xpol_variances/(sum(xpol_variances)));
stem(xpol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
xpol_num_components = find(xpol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% xpol_num_components =
%
%      8

% %% [markdown]
% ### Copolarized data

% %%
[copol_principal_components, copol_transformed_data, copol_variances] = pca(data.copol_processed');
copol_transformed_data = copol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
copol_explained_variance = cumsum(copol_variances/(sum(copol_variances)));
stem(copol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
copol_num_components = find(copol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% copol_num_components =
%
%      4

% %% [markdown]
% ### project and save the data

% %%
data.xpol_pca = xpol_transformed_data(1:xpol_num_components, :);
data.copol_pca = copol_transformed_data(1:copol_num_components, :);
save([datapath filesep 'processed_data_pca_10-05.mat'], 'data', '-v7.3');

% %% [markdown]
% # 10-06

% %%
load([datapath filesep 'processed_data_10-06.mat']);

% %% [markdown]
% ### Cross-polarized data

% %%
[xpol_principal_components, xpol_transformed_data, xpol_variances] = pca(data.xpol_processed');
xpol_transformed_data = xpol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
xpol_explained_variance = cumsum(xpol_variances/(sum(xpol_variances)));
stem(xpol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
xpol_num_components = find(xpol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% xpol_num_components =
%
%      4

% %% [markdown]
% ### Copolarized data

% %%
[copol_principal_components, copol_transformed_data, copol_variances] = pca(data.copol_processed');
copol_transformed_data = copol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
copol_explained_variance = cumsum(copol_variances/(sum(copol_variances)));
stem(copol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
copol_num_components = find(copol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% copol_num_components =
%
%      2

% %% [markdown]
% ### project and save the data

% %%
data.xpol_pca = xpol_transformed_data(1:xpol_num_components, :);
data.copol_pca = copol_transformed_data(1:copol_num_components, :);
save([datapath filesep 'processed_data_pca_10-06.mat'], 'data', '-v7.3');

% %% [markdown]
% # 10-07

% %%
load([datapath filesep 'processed_data_10-07.mat']);

% %% [markdown]
% ### Cross-polarized data

% %%
[xpol_principal_components, xpol_transformed_data, xpol_variances] = pca(data.xpol_processed');
xpol_transformed_data = xpol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
xpol_explained_variance = cumsum(xpol_variances/(sum(xpol_variances)));
stem(xpol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
xpol_num_components = find(xpol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% xpol_num_components =
%
%      6

% %% [markdown]
% ### Copolarized data

% %%
[copol_principal_components, copol_transformed_data, copol_variances] = pca(data.copol_processed');
copol_transformed_data = copol_transformed_data'; % transpose so observations are column vectors like in the original data

% %% [markdown]
% Find how many principal components are needed to explain 99% of the variance

% %%
copol_explained_variance = cumsum(copol_variances/(sum(copol_variances)));
stem(copol_explained_variance)
ylabel('explained variance')
xlabel('number of principal components')
copol_num_components = find(copol_explained_variance >= EXPLAINED_VARIANCE_THRESHOLD, 1)
% Out:
% copol_num_components =
%
%      3

% %% [markdown]
% ### project and save the data

% %%
data.xpol_pca = xpol_transformed_data(1:xpol_num_components, :);
data.copol_pca = copol_transformed_data(1:copol_num_components, :);
save([datapath filesep 'processed_data_pca_10-07.mat'], 'data', '-v7.3');

% %%
data
% Out:
% data =
%
%   struct with fields:
%
%            xpol_raw: [1000x682304 double]
%           copol_raw: [1000x682304 double]
%      xpol_processed: [150x682304 double]
%     copol_processed: [150x682304 double]
%              labels: [4x682304 double]
%            metadata: [1x1 struct]
%            xpol_pca: [6x682304 double]
%           copol_pca: [3x682304 double]
